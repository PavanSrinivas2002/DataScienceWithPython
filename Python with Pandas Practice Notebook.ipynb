# %%
import pandas as pd

# %%
csvpath=r"C:\Users\pavan\Downloads\practice.csv"
df=pd.read_csv(csvpath)
df
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 13927  2019                  all                     All Industries
# 13928  2019                  all                     All Industries
# 13929  2019                  all                     All Industries
# 13930  2019                  all                     All Industries
# 13931  2019                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
df2=df[['year']]
df2
# Out:
#        year
# 0      2011
# 1      2011
# 2      2011
# 3      2011
# 4      2011
# ...     ...
# 13927  2019
# 13928  2019
# 13929  2019
# 13930  2019
# 13931  2019
#
# [13932 rows x 1 columns]

# %%
df2['year'].unique()
# Out:
# array([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], dtype=int64)

# %%
df3=df[df['year']>2013]
df3
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 4644   2014                    A  Agriculture, Forestry and Fishing
# 4645   2014                    A  Agriculture, Forestry and Fishing
# 4646   2014                    A  Agriculture, Forestry and Fishing
# 4647   2014                    A  Agriculture, Forestry and Fishing
# 4648   2014                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 13927  2019                  all                     All Industries
# 13928  2019                  all                     All Industries
# 13929  2019                  all                     All Industries
# 13930  2019                  all                     All Industries
# 13931  2019                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 4644             a_0                                    Activity unit
# ...

# %%
df3.to_csv("2013.csv")
